# %%
k=[2,4,5,6,8,9,12,14,15,17,19]
print(k[0])
print(k[1])
print(k[2])
print(k[3])
print(k[4])                             #print the value of k[0],k[1],k[2],k[3],k[4]
# Out:
# 2
# 4
# 5
# 6
# 8

# %%
k=[2,4,5,6,8,9,12,14,15,17,19]
n=len(k)
mid_pos=n//2
print(mid_pos)                          #print the index of mid position of this list
# Out:
# 5

# %%
k=[2,4,5,6,8,9,12,14,15,17,19]
print(k[5])                           #print the value at index of mid position of this list
# Out:
# 9

# %%
k=[12,14,15,16,18,19,22,24,25,27,29,39,40,42,45,47,49]
print(k[0])
print(k[1])
print(k[2])
print(k[3])
print(k[4])
print(k[5])
print(k[6])
print(k[7])
print(k[8]) 
print(k[0:16])               #print the value of k(0),k(1),k(2),k(3),k(4),k(5),k(6),k(7),k(8)
# Out:
# 12
# 14
# 15
# 16
# 18
# 19
# 22
# 24
# 25
# [12, 14, 15, 16, 18, 19, 22, 24, 25, 27, 29, 39, 40, 42, 45, 47]

# %%
#  print the mid position of 

k=[12,14,15,16,18,19,22,24,25,27,29,39,40,42,45,47,49]
n=len(k)
mid_pos=n//2
print(mid_pos)


#
print(k[mid_pos])
# Out:
# 8
# 25

# %%
M=[12,14,15]
print(M[0])
print(M[1])
print(M[2])
# Out:
# 12
# 14
# 15

# %%
M=[12,14,15]
N=len(M)
mid_pos=N//2
print(mid_pos)
# Out:
# 1

# %%
M=[12,14,15]
N=len(M)

mid_pos=N//2
print(mid_pos)
print(M[mid_pos])
# Out:
# 1
# 14

# %%
#print the value of p[0],p[1],p[2],p[3]

p=[12,14,15,16]
print(p[:4])
# Out:
# [12, 14, 15, 16]

# %%
#b print the value of index of this list.

p=[12,14,15,16]
n=len(p)
midpos1,midpos2=n//2,n//2-1
print(midpos1,midpos2)

#c print the  value at index of midpos of this list. 

print(p[midpos1])
print(p[midpos2])
# Out:
# 2 1
# 15
# 14

# %%
#a print the value of Q[0],Q[1],Q[2],Q[3]

Q=[12,14,15,16,18,19]
print(Q[0:4])
# Out:
# [12, 14, 15, 16]

# %%
#b print the index of midposition of this list.

Q=[12,14,15,16,18,19]
n=len(Q)
midpos1=n//2
midpos2=n//2-1
print("mid index is ",midpos1)
print("mid index is ",midpos2)
# Out:
# mid index is  3
# mid index is  2

# %%
#c print the vaalue at index of mid position of this list

Q=[12,14,15,16,18,19]
n=len(Q)
midpos1=n//2
midpos2=n//2-1
print("mid index is ",midpos1)
print("mid index is ",midpos2)
print(Q[midpos1],Q[midpos2])
# Out:
# mid index is  3
# mid index is  2
# 16 15

# %%
#a print the value of R[0],R[1],R[2]

R=[12,14,15,16,18,19,20,22]
print(R[0:3])

#b print the index of mid position of this list.
 
n=len(R)
midpos1=n//2
midpos2=n//2-1
print("mid index is ",midpos1)
print("mid index is ",midpos2)

#c print the value at index of mid position of this list.

print(R[midpos1])
print(R[midpos2])
# Out:
# [12, 14, 15]
# mid index is  4
# mid index is  3
# 18
# 16

# %%
#a print the value of S[0],S[1],S[2],S[4],S[5],S[6],S[7],S[8],S[9]

S=[12,14,15,16,18,19,20,22,24,28]
print(S[0:10])

#b print the index of mid position of this list.
 
n=len(S)
midpos1=n//2
midpos2=n//2-1
print("mid index is ",midpos1)
print("mid index is ",midpos2)

#c print the value at index of mid position of this list.

print(S[midpos1])
print(S[midpos2])
# Out:
# [12, 14, 15, 16, 18, 19, 20, 22, 24, 28]
# mid index is  5
# mid index is  4
# 19
# 18
