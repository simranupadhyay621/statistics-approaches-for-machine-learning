# %%
list=[1,2,3,4,5]
sum=sum(list)
count=len(list)
print (sum)
print (count)
# Out:
# 15
# 5

# %%
list=[14,42,17,19]
sum=sum(list)
count=len(list)
print(sum)
print(count)
# Out:
# 92
# 4

# %%
list=[24,73,56,28,19,18,17]
sum_l=sum(list)
count=len(list)
mean=sum_l/count
print(mean)
print(sum_l)
print(count)
# Out:
# 33.57142857142857
# 235
# 7

# %%
list=[24,73,67,98,18,19,34,71,68,54,33]
sum_l=sum(list)
count=len(list)
mean=sum_l/count
print(sum_l)
print(count)
print(mean)
# Out:
# 559
# 11
# 50.81818181818182

# %%
list=[24,19,18,17,34,71]
sum_l=sum(list)
count=len(list)
mean=sum_l/count
print(sum_l)
print(count)
print(mean)
# Out:
# 183
# 6
# 30.5
